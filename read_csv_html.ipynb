# %%
import pandas as pd
import numpy as np

file_to_load ="Resources/cities.csv"

cities_df = pd.read_csv(file_to_load)
cities_df.head()
# Out:
#               City Country  Latitude  Longitude        Date  Cloudiness  \
# 0     Punta Arenas      CL    -53.15     -70.92  1594685099          90
# 1  Nieuw Amsterdam      SR      5.88     -55.08  1594685100          40
# 2       Bredasdorp      ZA    -34.53      20.04  1594685101          70
# 3        Cape Town      ZA    -33.93      18.42  1594685101          75
# 4          Barsovo      RU     61.17      73.17  1594685101           1
#
#    Humidity  Max Temp  Wind Speed
# 0        80      35.6        8.05
# 1        83      80.6        8.05
# 2        87      46.4       13.87
# 3        76      52.0        8.05
# 4        87      57.2        8.95

# %%
cities_df.to_html("cities.html")
